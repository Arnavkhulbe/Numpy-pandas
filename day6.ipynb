# %%
import pandas as pd

# %%
df=pd.read_csv("joined.csv")
print(df)
# Out:
#    Attendance  Marks
# 0          90     85
# 1          85     78
# 2          88     88
# 3          97     95

# %%
df.to_csv("newjoined.csv", index=False)

# %%
import pandas as pd

# %%
excel=pd.read_excel("students.xlsx")
print(excel)
#iske liye file same folder mai honi chahiye

# %%
df.to_excel("output.xlsx", index=False)

# %%
import pandas as pd
df = pd.read_csv("students.csv")

# %%
with pd.ExcelWriter("report.xlsx") as writer:
    df.to_excel(writer, sheet_name="Student Data", index=False)
    df.describe().to_excel(writer, sheet_name="Statistics")

# %%
import pandas as pd#importing json file 

df_json = pd.read_json("students.json")
print(df_json)

# %%
df_json.to_csv("json_to_csv.csv", index=False)   #JSON → CSV Export
